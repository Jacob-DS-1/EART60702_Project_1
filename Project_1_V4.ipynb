# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
df = pd.read_csv('project_1.csv')
df.head()
# Out:
#                   time  TREFMXAV_U       FLNS       FSNS         PRECT  \
# 0  2006-01-02 00:00:00   282.77585  41.925180  25.926952  4.663135e-09
# 1  2006-01-03 00:00:00   284.47113   8.905806  10.946910  8.046593e-08
# 2  2006-01-04 00:00:00   284.28796  16.511415   6.405902  2.910936e-09
# 3  2006-01-05 00:00:00   282.12110  29.948362   9.315041  7.432505e-11
# 4  2006-01-06 00:00:00   280.89090  19.064156   7.941241  6.894238e-12
#
#            PRSN      QBOT     TREFHT      UBOT      VBOT        lat    lon
# 0  4.781004e-17  0.004769  279.14288  3.878579  1.394184  53.246075  357.5
# 1  1.295726e-16  0.006271  281.14865  1.788157  3.821703  53.246075  357.5
# 2  4.094447e-16  0.005782  281.22380  0.804845 -2.299140  53.246075  357.5
# 3  0.000000e+00  0.004277  278.39767 -1.100267 -1.258029  53.246075  357.5
# 4  0.000000e+00  0.003990  278.06378 -0.706321 -0.938421  53.246075  357.5

# %%
df.shape
# Out:
# (27374, 12)

# %% [markdown]
# 12 columns, 27374 rows

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27374 entries, 0 to 27373
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   time        27374 non-null  object
#  1   TREFMXAV_U  27374 non-null  float64
#  2   FLNS        27374 non-null  float64
#  3   FSNS        27374 non-null  float64
#  4   PRECT       27374 non-null  float64
#  5   PRSN        27374 non-null  float64
#  6   QBOT        27374 non-null  float64
#  7   TREFHT      27374 non-null  float64
#  8   UBOT        27374 non-null  float64
#  9   VBOT        27374 non-null  float64
#  10  lat         27374 non-null  float64
#  11  lon         27374 non-null  float64
# dtypes: float64(11), object(1)
# memory usage: 2.5+ MB

# %% [markdown]
# No missing data

# %%
df.describe()
# Out:
#          TREFMXAV_U          FLNS          FSNS         PRECT          PRSN  \
# count  27374.000000  27374.000000  27374.000000  2.737400e+04  2.737400e+04
# mean     288.836179     42.995679     97.026261  3.379697e-08  3.049825e-10
# std        5.246468     21.451927     75.062880  4.986518e-08  4.706017e-09
# min      274.153200      0.611385      2.819259 -4.671764e-28 -6.256338e-21
# 25%      284.719465     26.157544     31.037187  2.131118e-09  0.000000e+00
# 50%      288.299895     40.777005     78.443183  1.311730e-08  1.206375e-21
# 75%      292.869525     57.113572    149.332133  4.637272e-08  2.348279e-16
# max      311.257260    111.851400    310.191700  7.752961e-07  2.332090e-07
#
#                QBOT        TREFHT          UBOT          VBOT           lat  \
# count  27374.000000  27374.000000  27374.000000  27374.000000  2.737400e+04
# mean       0.006523    284.876413      1.176320      1.503084  5.324608e+01
# std        0.002126      4.992277      3.066843      2.940138  1.659148e-11
# min        0.001855    268.938400     -9.739025     -8.991429  5.324607e+01
# 25%        0.004860    280.987885     -1.085982     -0.766405  5.324607e+01
# 50%        0.006211    284.537575      1.488009      1.593354  5.324607e+01
# 75%        0.007947    288.900110      3.390555      3.634500  5.324607e+01
# max        0.015222    303.117980     10.234506     11.178102  5.324607e+01
#
#            lon
# count  27374.0
# mean     357.5
# std        0.0
# min      357.5
# 25%      357.5
# 50%      357.5
# 75%      357.5
# max      357.5

# %%
df['time'] = pd.to_datetime(df['time'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27374 entries, 0 to 27373
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   time        27374 non-null  datetime64[ns]
#  1   TREFMXAV_U  27374 non-null  float64
#  2   FLNS        27374 non-null  float64
#  3   FSNS        27374 non-null  float64
#  4   PRECT       27374 non-null  float64
#  5   PRSN        27374 non-null  float64
#  6   QBOT        27374 non-null  float64
#  7   TREFHT      27374 non-null  float64
#  8   UBOT        27374 non-null  float64
#  9   VBOT        27374 non-null  float64
#  10  lat         27374 non-null  float64
#  11  lon         27374 non-null  float64
# dtypes: datetime64[ns](1), float64(11)
# memory usage: 2.5 MB

# %%
print(f"Number of unique latitudes: {df['lat'].nunique()}")
print(f"Number of unique longitudes: {df['lon'].nunique()}")
# Out:
# Number of unique latitudes: 1
# Number of unique longitudes: 1

# %% [markdown]
# All measurements are taken at a single location - drop and keep in metadata only

# %%
cols_to_drop = ['lat', 'lon']

df = df.drop(columns=cols_to_drop)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27374 entries, 0 to 27373
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   time        27374 non-null  datetime64[ns]
#  1   TREFMXAV_U  27374 non-null  float64
#  2   FLNS        27374 non-null  float64
#  3   FSNS        27374 non-null  float64
#  4   PRECT       27374 non-null  float64
#  5   PRSN        27374 non-null  float64
#  6   QBOT        27374 non-null  float64
#  7   TREFHT      27374 non-null  float64
#  8   UBOT        27374 non-null  float64
#  9   VBOT        27374 non-null  float64
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 2.1 MB

# %% [markdown]
# Give some geographical context to the location site

# %%
import folium

map = folium.Map(location=[53.246075,357.5], zoom_start=13)
folium.Marker([53.246075,357.5], popup='Measurement Site').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0cbe99be795033470028df643cfc1ebe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0cbe99be795033470028df643cfc1ebe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0cbe99be795033470028df643cfc1ebe = L.map(
#                 &quot;map_0cbe99be795033470028df643cfc1ebe&quot;,
#                 {
#                     center: [53.246075, 357.5],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2e0419bbafa0b26332ad4acdffb6651c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2e0419bbafa0b26332ad4acdffb6651c.addTo(map_0cbe99be795033470028df643cfc1ebe);
#
#
#             var marker_64674b2f967cf6ce875b3194a6c8b3c1 = L.marker(
#                 [53.246075, 357.5],
#                 {
# }
#             ).addTo(map_0cbe99be795033470028df643cfc1ebe);
#
#
#         var popup_fdbcef3de3e56aad5d8c17b3aa190204 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0d2f9ccd7c541d67dad5d69b8381ed5 = $(`&lt;div id=&quot;html_d0d2f9ccd7c541d67dad5d69b8381ed5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Measurement Site&lt;/div&gt;`)[0];
#                 popup_fdbcef3de3e56aad5d8c17b3aa190204.setContent(html_d0d2f9ccd7c541d67dad5d69b8381ed5);
#
#
#
#         marker_64674b2f967cf6ce875b3194a6c8b3c1.bindPopup(popup_fdbcef3de3e56aad5d8c17b3aa190204)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Find heading code meanings and store in dictionary

# %%
heading_meanings = {
    'TREFMXAV_U' : 'Urban daily maximum of average 2-m temperature / K',
    'FLNS' : 'Net longwave flux at surface / Wm^-2',
    'FSNS' : 'Net solar flux at surface / Wm^-2',
    'PRECT' : 'Total (convective and large-scale) precipitation rate (liq + ice) / ms^-1',
    'PRSN' : 'Currently unknown',
    'QBOT' : 'Lowest model level water vapor mixing ratio',
    'TREFHT' : 'Reference height temperature / K',
    'UBOT' : 'Lowest model level zonal wind / ms^-1',
    'VBOT' : 'Lowest model level meridional wind / ms^-1',
    'lat' : 'Latitude of measurement site / degrees = 53.246075',
    'lon' : 'Longitude of measurement site / degrees = 357.5'
}

# %% [markdown]
# Research suggests PRSN is snow precipitation i.e. snowfall (solid precipitation) flux/rate at the surface, expressed as liquid-water equivalent
#
# To confirm:
#
# - Bound check: 0 ≤ PRSN ≤ PRECT should hold almost everywhere
#     - If true, then PRECT - PRSN is effectively the rain component
# - Temperature check: PRSN should spike primarily when TREFHT is near/below 273.15 K (freezing)

# %%
# Bound check

no_cond_met = len(df[(df['PRSN'] >= 0) & (df['PRSN'] <= df['PRECT'])])
prop_cond_met = no_cond_met / df.shape[0]

print(f"{(prop_cond_met * 100):.2f}% of the data meets the bound check.")
# Out:
# 96.17% of the data meets the bound check.

# %%
# Temp check

sns.scatterplot(x=df['TREFHT'], y=df['PRSN'], marker='o', color='blue')
plt.xlabel('Temperature')
plt.ylabel('Precipitation?')
plt.title('Temperature vs Precipitation?')
plt.savefig('temp_check.png', dpi=300, bbox_inches='tight')
plt.draw()
plt.show()

# %% [markdown]
# Clear spike around freezing point of water
#
# Both checks passed

# %%
# Update metadata dictionary and make df

heading_meanings['PRSN'] = 'Snow precipitation (solid precipitation) flux/rate at the surface, expressed as liquid-water equivalent / ms^-1'

meta_df = pd.DataFrame({'Column': list(heading_meanings.keys()), 
                       'Meaning': list(heading_meanings.values())})
meta_df
# Out:
#         Column                                            Meaning
# 0   TREFMXAV_U  Urban daily maximum of average 2-m temperature...
# 1         FLNS               Net longwave flux at surface / Wm^-2
# 2         FSNS                  Net solar flux at surface / Wm^-2
# 3        PRECT  Total (convective and large-scale) precipitati...
# 4         PRSN  Snow precipitation (solid precipitation) flux/...
# 5         QBOT        Lowest model level water vapor mixing ratio
# 6       TREFHT                   Reference height temperature / K
# 7         UBOT              Lowest model level zonal wind / ms^-1
# 8         VBOT         Lowest model level meridional wind / ms^-1
# 9          lat  Latitude of measurement site / degrees = 53.24...
# 10         lon    Longitude of measurement site / degrees = 357.5

# %%
corr_matrix = df.corr()

print(corr_matrix)
# Out:
#                 time  TREFMXAV_U      FLNS      FSNS     PRECT      PRSN  \
# time        1.000000    0.188005  0.028905  0.063487 -0.017728 -0.031175
# TREFMXAV_U  0.188005    1.000000  0.219688  0.721310 -0.103835 -0.116976
# FLNS        0.028905    0.219688  1.000000  0.683627 -0.473853 -0.059749
# FSNS        0.063487    0.721310  0.683627  1.000000 -0.329469 -0.064145
# PRECT      -0.017728   -0.103835 -0.473853 -0.329469  1.000000  0.117777
# PRSN       -0.031175   -0.116976 -0.059749 -0.064145  0.117777  1.000000
# QBOT        0.157445    0.791619 -0.304497  0.251489  0.213600 -0.078040
# TREFHT      0.177089    0.967620  0.025457  0.605906 -0.026978 -0.123028
# UBOT        0.013412   -0.167388 -0.028396 -0.169522 -0.000641 -0.051850
# VBOT       -0.011024   -0.126361 -0.273296 -0.335963  0.252043 -0.037847
#
#                 QBOT    TREFHT      UBOT      VBOT
# time        0.157445  0.177089  0.013412 -0.011024
# TREFMXAV_U  0.791619  0.967620 -0.167388 -0.126361
# FLNS       -0.304497  0.025457 -0.028396 -0.273296
# FSNS        0.251489  0.605906 -0.169522 -0.335963
# PRECT       0.213600 -0.026978 -0.000641  0.252043
# PRSN       -0.078040 -0.123028 -0.051850 -0.037847
# QBOT        1.000000  0.876221 -0.142494  0.023922
# TREFHT      0.876221  1.000000 -0.125189 -0.084132
# UBOT       -0.142494 -0.125189  1.000000  0.248370
# VBOT        0.023922 -0.084132  0.248370  1.000000

# %%
plt.figure(figsize=(10,8))

sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, 
            fmt='.2f', linewidths=0.5)

plt.title("Correlation matrix", fontsize=16, fontweight='bold')

plt.tight_layout()
plt.savefig('corr_mat.png', dpi=300, bbox_inches='tight')
plt.draw()
plt.show()

# %%
print(df['time'].max())
# Out:
# 2080-12-31 00:00:00

# %%
print(df['time'].min())
# Out:
# 2006-01-02 00:00:00

# %% [markdown]
# Good opportunity to look at long term changes over the century
#
# Check format of datetime data

# %%
df['time'] = pd.to_datetime(df['time'])
df.loc[(df['time'].dt.month==2) & (df['time'].dt.day==29), 'time'].head()
# Out:
# Series([], Name: time, dtype: datetime64[ns])

# %%
days_per_year = df.groupby(df['time'].dt.year).size()
days_per_year.value_counts().sort_index()
# Out:
# 364     1
# 365    74
# Name: count, dtype: int64

# %%
full = pd.date_range(df['time'].min().normalize(), df['time'].max().normalize(), freq='D')
missing = full.difference(df['time'])
missing[:30], len(missing)
# Out:
# (DatetimeIndex(['2008-02-29', '2012-02-29', '2016-02-29', '2020-02-29',
#                 '2024-02-29', '2028-02-29', '2032-02-29', '2036-02-29',
#                 '2040-02-29', '2044-02-29', '2048-02-29', '2052-02-29',
#                 '2056-02-29', '2060-02-29', '2064-02-29', '2068-02-29',
#                 '2072-02-29', '2076-02-29', '2080-02-29'],
#                dtype='datetime64[ns]', freq=None),
#  19)

# %% [markdown]
# Using 365 day calendar for all years (no leap years)

# %% [markdown]
# ## What are the long-term trends in warming, urban heat amplification, and extreme weather events at this location?

# %% [markdown]
# ### Long-term warming trends

# %%
df['year'] = df['time'].dt.year
df['month'] = df['time'].dt.month
df['day'] = df['time'].dt.day

df.drop(['time'], axis=1, inplace=True)

annual_df = df.copy().drop(['month', 'day'], axis=1).groupby('year').mean().reset_index()

annual_df.head()
# Out:
#    year  TREFMXAV_U       FLNS       FSNS         PRECT          PRSN  \
# 0  2006  287.215171  41.931870  87.163589  3.341157e-08  3.174364e-10
# 1  2007  287.660296  43.446521  91.296121  3.464801e-08  1.388909e-10
# 2  2008  287.674791  42.721781  88.977344  3.836932e-08  1.619013e-11
# 3  2009  287.066897  40.063709  86.047715  3.419310e-08  7.733756e-10
# 4  2010  287.782010  45.446871  96.741252  3.425257e-08  3.618069e-10
#
#        QBOT      TREFHT      UBOT      VBOT
# 0  0.006033  283.340474  0.896966  1.547436
# 1  0.006034  283.801151  1.797941  2.305364
# 2  0.006165  283.790595  1.132939  2.093794
# 3  0.006059  283.436362  0.031906  0.978087
# 4  0.006024  283.783431  0.794693  1.438022

# %%
plt.style.use('seaborn-v0_8-whitegrid')
sns.set_context("notebook", font_scale=1.1)

temp_year_p_corr = annual_df['TREFHT'].corr(annual_df['year'])

plt.figure(figsize=(10,8))
sns.regplot(x='year', y='TREFHT', data=annual_df, color='k',
            ci=None, line_kws={'linewidth':1.5},
            label=f"Pearson correlation coefficient: {temp_year_p_corr:.3f}",
            scatter_kws={'color':'orange', 's':50}
           )
plt.xlabel('Year', labelpad=10)
plt.ylabel(meta_df.loc[meta_df['Column']=='TREFHT', 'Meaning'].values[0], labelpad=10)
plt.legend(loc='upper left', frameon=True, fontsize=12, facecolor='lightgray', framealpha=0.8)
plt.title('Long-term temperature trend in Manchester (2006-2080)', fontweight='bold', fontsize=15, pad=15)
for spine in plt.gca().spines.values():
    spine.set_color('k')
plt.tight_layout()
plt.savefig('temp_year_scatter.png', dpi=300, bbox_inches='tight')
plt.draw()
plt.show()

# %%
plt.figure(figsize=(10,8))

temp_urb_p_corr = annual_df['TREFHT'].corr(annual_df['TREFMXAV_U'])

sns.regplot(x='TREFHT', y='TREFMXAV_U', data=annual_df, color='k',
            ci=None, line_kws={'linewidth':1.5},
            label=f"Pearson correlation coefficient: {temp_urb_p_corr:.3f}",
            scatter_kws={'color':'orange', 's':50}
           )
plt.xlabel(meta_df.loc[meta_df['Column']=='TREFHT', 'Meaning'].values[0], labelpad=10)
plt.ylabel(meta_df.loc[meta_df['Column']=='TREFMXAV_U', 'Meaning'].values[0], labelpad=10)
plt.legend(loc='upper left', frameon=True, fontsize=12, facecolor='lightgray', framealpha=0.8)
plt.title('Long-term relationship between reference height ambient temperature and urban maximum temperature (2006-2080)', fontweight='bold', fontsize=15, pad=15)
for spine in plt.gca().spines.values():
    spine.set_color('k')
plt.tight_layout()
plt.savefig('urbtemp_temp_scatter.png', dpi=300, bbox_inches='tight')
plt.draw()
plt.show()

# %%
# Hue by year to illustrate how this warming increases over the century

plt.figure(figsize=(10,8))

temp_urb_p_corr = annual_df['TREFHT'].corr(annual_df['TREFMXAV_U'])

min_year = annual_df['year'].min()
max_year = annual_df['year'].max()

custom_palette = sns.color_palette("viridis", n_colors=len(annual_df['year'].unique()))

g = sns.lmplot(x='TREFHT', y='TREFMXAV_U', data=annual_df, 
               hue='year', palette=custom_palette, height=8, aspect=1.25,
               scatter_kws={'s': 50},
               line_kws={'color': 'k', 'linewidth': 1.5},
               ci=None, legend=False)

plt.xlabel(meta_df.loc[meta_df['Column']=='TREFHT', 'Meaning'].values[0], labelpad=10)
plt.ylabel(meta_df.loc[meta_df['Column']=='TREFMXAV_U', 'Meaning'].values[0], labelpad=10)
plt.title('Long-term relationship between reference height ambient temperature and urban maximum temperature (2006-2080) hued by year', 
          fontweight='bold', fontsize=15, pad=15)

plt.text(0.05, 0.95, f"Pearson correlation coefficient: {temp_urb_p_corr:.3f}", 
         transform=plt.gca().transAxes, fontsize=12, 
         bbox=dict(facecolor='lightgray', alpha=0.8))

cmap = plt.cm.viridis
sm = plt.cm.ScalarMappable(cmap=cmap, 
                           norm=plt.Normalize(min_year, max_year))
sm.set_array([])
cbar = plt.colorbar(sm, ax=g.axes[0,0], orientation='vertical', pad=0.01)
cbar.set_label('Year', rotation=270, labelpad=20)
cbar.set_ticks([min_year, max_year])
cbar.set_ticklabels([str(min_year), str(max_year)])

for spine in plt.gca().spines.values():
    spine.set_color('k')

plt.tight_layout()
plt.savefig('urbtemp_temp_scatter_hued.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# WMO stipulate that a 30 year period constitues the 'climate' at a location

# %%
baseline_mask = (df['year'] >= 2006) & (df['year'] <= 2035)
future_mask = (df['year'] >= 2051) & (df['year'] <= 2080)

baseline_data = df[baseline_mask]

# %%
# Reference height temp

baseline_montly_mean_temp = df[baseline_mask].groupby('month')['TREFHT'].mean()
future_monthly_mean_temp = df[future_mask].groupby('month')['TREFHT'].mean()

# Calculate overall average temperature increase in degrees
delta_t = df[future_mask]['TREFHT'].mean() - df[baseline_mask]['TREFHT'].mean()

stats_label = (
    f"Mean Shift: +{delta_t:.2f} K\n"
)

plt.figure(figsize=(10, 6))

plt.plot(baseline_montly_mean_temp.index,
         baseline_montly_mean_temp.values, 'o-',
         label='Baseline mean monthly reference\nheight temperatures (2006-2035)', lw=2
        )
plt.plot(future_monthly_mean_temp.index,
         future_monthly_mean_temp.values, 's-',
         label='Future mean monthly reference\nheight temperatures (2036-2080)', color='red', lw=2)
plt.fill_between(baseline_montly_mean_temp.index, baseline_montly_mean_temp.values, future_monthly_mean_temp.values, color='red', alpha=0.1)

plt.plot([], [], ' ', label=stats_label.replace(', ', ',\n')) 

plt.title('Long-term shift in monthly mean climate normal temperature (2006-2080)', fontweight='bold', fontsize=15, pad=15)
plt.xlabel('Month', labelpad=10)
plt.ylabel(meta_df.loc[meta_df['Column']=='TREFHT', 'Meaning'].values[0], labelpad=10)
plt.xticks(range(1, 13))
legend = plt.legend(loc='upper left', frameon=True, fontsize=12, facecolor='lightgray', framealpha=0.8, labelspacing=1.5)
for text in legend.get_texts():
    text.set_linespacing(1.5)
for spine in plt.gca().spines.values():
    spine.set_color('k')
plt.tight_layout()
plt.savefig('temp_base_vs_future_line.png', dpi=300, bbox_inches='tight')
plt.draw()
plt.show()

# %%
# Same for urban daily max temp

baseline_montly_mean_urb_temp = df[baseline_mask].groupby('month')['TREFMXAV_U'].mean()
future_monthly_mean_urb_temp = df[future_mask].groupby('month')['TREFMXAV_U'].mean()

# Calculate overall average temperature increase in degrees
delta_t = df[future_mask]['TREFMXAV_U'].mean() - df[baseline_mask]['TREFMXAV_U'].mean()

stats_label = (
    f"Mean Shift: +{delta_t:.2f} K\n"
)

plt.figure(figsize=(10, 6))

plt.plot(baseline_montly_mean_urb_temp.index,
         baseline_montly_mean_urb_temp.values, 'o-',
         label='Baseline mean monthly\nurban daily maximum\ntemperatures (2006-2035)', lw=2
        )
plt.plot(future_monthly_mean_urb_temp.index,
         future_monthly_mean_urb_temp.values, 's-',
         label='Future mean monthly\nurban daily maximum\ntemperatures (2036-2080)', color='red', lw=2)
plt.fill_between(baseline_montly_mean_urb_temp.index, baseline_montly_mean_urb_temp.values, future_monthly_mean_urb_temp.values, color='red', alpha=0.1)

plt.plot([], [], ' ', label=stats_label.replace(', ', ',\n')) 

plt.title('Long-term shift in monthly mean climate normal urban temperature (2006-2080)', fontweight='bold', fontsize=15, pad=15)
plt.xlabel('Month', labelpad=10)
plt.ylabel(meta_df.loc[meta_df['Column']=='TREFMXAV_U', 'Meaning'].values[0], labelpad=10)
plt.xticks(range(1, 13))
legend = plt.legend(loc='upper left', frameon=True, fontsize=12,
                    facecolor='lightgray', framealpha=0.8,
                    labelspacing=1.5, bbox_to_anchor=(1.05, 0.75),
                    borderaxespad=0
                   )
for text in legend.get_texts():
    text.set_linespacing(1.5)
for spine in plt.gca().spines.values():
    spine.set_color('k')
plt.tight_layout(rect=[0, 0, 1, 1])
plt.savefig('urbtemp_base_vs_future_line.png', dpi=300, bbox_inches='tight')
plt.draw()
plt.show()

# %% [markdown]
# Split data into 15 year 'blocks' to explore shifts over the century

# %%
df['block'] = ((df['year'] - 2006) // 15) * 15 + 2006

means_vars = ['TREFHT', 'TREFMXAV_U']

monthly_means = (
    df.groupby(['block', 'month'])[means_vars]
    .mean()
    .reset_index()
)

block_ranges = df.groupby("block")["year"].agg(min_year="min", max_year="max").sort_values("min_year")
label_map = {b: f"{r.min_year}\u2013{r.max_year}" for b, r in block_ranges.iterrows()}

monthly_means = monthly_means.copy()
monthly_means["block_label"] = monthly_means["block"].map(label_map)

hue_order = [label_map[b] for b in block_ranges.index]

n = len(hue_order)

# Light to dark as time progresses
pal = sns.color_palette("viridis", n_colors=n)[::-1]
palette = dict(zip(hue_order, pal))

unit_map = {
    "TREFHT": r"K",
    "TREFMXAV_U": r"K",
}

n_rows, n_cols = 1, 2
vars_to_plot = monthly_means.columns[2:-1].tolist()

total_subplots = n_rows * n_cols
if total_subplots < len(vars_to_plot):
    n_rows = (len(vars_to_plot) + n_cols - 1) // n_cols

fig, axes = plt.subplots(n_rows, n_cols, figsize=(14, 6), sharex=True)
axes = axes.ravel()

handles = labels = None

for i, (ax, var) in enumerate(zip(axes, vars_to_plot)):
    show_leg = (i == 0)

    sns.lineplot(
        data=monthly_means,
        x="month",
        y=var,
        hue="block_label",
        hue_order=hue_order,
        palette=palette,
        ax=ax,
        legend=show_leg
    )

    # unit = unit_map.get(var, "")
    # ylabel = f"{var} ({unit})" if unit else var
    ylabel = meta_df.loc[meta_df['Column']==var, 'Meaning'].values[0]

    ax.set_xlabel("Month", labelpad=10)
    ax.set_ylabel(ylabel, labelpad=10)
    ax.set_xticks(range(1, 13))
    ax.grid(True, alpha=0.3)

    if show_leg and ax.legend_ is not None:
        handles, labels = ax.get_legend_handles_labels()
        ax.legend_.remove()

# delete unused axes
for j in range(len(vars_to_plot), len(axes)):
    fig.delaxes(axes[j])

for ax in axes[:len(vars_to_plot)]:
    for spine in ax.spines.values():
        spine.set_color("black")

# shared legend
if labels:
    fig.legend(
        handles, labels,
        title="Period",
        loc="upper center",
        bbox_to_anchor=(0.5, 1),
        ncol=min(len(labels), 5),
        frameon=True,
        fontsize=12,
        facecolor='lightgray',
        framealpha=0.7,
        labelspacing=1.5
    )

fig.suptitle('Long-term shifts in mean monthly temperatures (2006-2080)', fontweight='bold', fontsize=15, y=1.05)
plt.tight_layout(rect=[0, 0, 1, 0.85])
plt.subplots_adjust(wspace=0.2)
plt.savefig('temps_shifts_line.png', dpi=300, bbox_inches='tight')
plt.draw()
plt.show()

# %% [markdown]
# ### UHI index trend

# %% [markdown]
# Examine trend in UHI index over the century

# %%
# Urban heat island
df['UHI_Index'] = df['TREFMXAV_U'] - df['TREFHT']

annual_df = df.copy().drop(['month', 'day'], axis=1).groupby('year')['UHI_Index'].mean().reset_index()

plt.figure(figsize=(10,8))

uhi_year_p_corr = annual_df['UHI_Index'].corr(annual_df['year'])
# Include spearman corr too (see below)
uhi_year_s_corr = annual_df['UHI_Index'].corr(annual_df['year'], method='spearman')

labels = (
    f"Pearson correlation coefficient: {uhi_year_p_corr:.3f}\n\n"
    f"Spearman correlation coefficient: {uhi_year_s_corr:.3f}"
)

sns.regplot(x='year', y='UHI_Index', data=annual_df, color='k',
            ci=None, line_kws={'linewidth':1.5},
            label=labels,
            scatter_kws={'color':'orange', 's':50}
           )
plt.xlabel('Year', labelpad=10)
plt.ylabel('UHI index / K', labelpad=10)
plt.legend(loc='upper left', frameon=True, fontsize=12, facecolor='lightgray', framealpha=0.8)
plt.title('Long-term trend in urban heat island index (2006-2080)', fontweight='bold', fontsize=15, pad=15)
for spine in plt.gca().spines.values():
    spine.set_color('k')
plt.tight_layout()
plt.savefig('uhi_year_scatter.png', dpi=300, bbox_inches='tight')
plt.draw()
plt.show()

# %% [markdown]
# Check linearity assumption for this relationship

# %%
import statsmodels.api as sm

X = sm.add_constant(annual_df['year']) # Add intercept
y = annual_df['UHI_Index']

model = sm.OLS(y, X).fit()

annual_df['fitted'] = model.fittedvalues
annual_df['residuals'] = model.resid

print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              UHI_Index   R-squared:                       0.494
# Model:                            OLS   Adj. R-squared:                  0.487
# Method:                 Least Squares   F-statistic:                     71.22
# Date:                Sat, 21 Feb 2026   Prob (F-statistic):           2.10e-12
# Time:                        16:32:15   Log-Likelihood:                 62.403
# No. Observations:                  75   AIC:                            -120.8
# Df Residuals:                      73   BIC:                            -116.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -5.8552      1.163     -5.034      0.000      -8.173      -3.537
# year           0.0048      0.001      8.439      0.000       0.004       0.006
# ==============================================================================
# Omnibus:                        1.339   Durbin-Watson:                   2.185
# Prob(Omnibus):                  0.512   Jarque-Bera (JB):                1.264
# Skew:                           0.308   Prob(JB):                        0.532
# Kurtosis:                       2.838   Cond. No.                     1.93e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.93e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
plt.figure(figsize=(8, 6))

# Residuals vs fitted values
sns.scatterplot(x='fitted', y='residuals', data=annual_df, color='orange', s=60)

# Add a smooth trend line (LOWESS) to reveal curvature
sns.regplot(
    x='fitted', y='residuals', data=annual_df,
    lowess=True, scatter=False, ci=None,
    line_kws={'color': 'blue', 'linewidth': 2}
)

plt.axhline(0, color='k', linestyle='--', linewidth=1)
plt.xlabel('Fitted UHI index / K')
plt.ylabel('Residuals / K')
plt.title('Residuals vs Fitted', fontweight='bold')
plt.tight_layout()
plt.savefig('uhi_residual_vs_fitted.png', dpi=300, bbox_inches='tight')
plt.draw()
plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.scatterplot(x='year', y='residuals', data=annual_df, color='orange', s=60)

sns.regplot(
    x='year', y='residuals', data=annual_df,
    lowess=True, scatter=False, ci=None,
    line_kws={'color': 'blue', 'linewidth': 2}
)

plt.axhline(0, color='k', linestyle='--', linewidth=1)
plt.xlabel('Year')
plt.ylabel('Residuals / K')
plt.title('Residuals vs Year', fontweight='bold')
plt.tight_layout()
plt.savefig('uhi_residuals_vs_year.png', dpi=300, bbox_inches='tight')
plt.draw()
plt.show()

# %% [markdown]
# Interpretation:
#
# Residual plots don't show severe violation of linearity - linear trend is a reasonable assumption. Slight curvature in the LOWESS line suggests some mild nonlinearity. Hence we include Spearman correlation coefficient too

# %% [markdown]
# ### Extreme weather events: temperature, precipitation, compound

# %% [markdown]
# Explore how the frequency of extreme weather events changes over the century

# %%
# Original approach
temp_thresh = baseline_data['TREFMXAV_U'].quantile(0.90)
precip_thresh = baseline_data['PRECT'].quantile(0.95)

df['is_extreme_temp'] = df['TREFMXAV_U'] > temp_thresh
df['is_extreme_precip'] = df['PRECT'] > precip_thresh
df['is_extreme_both'] = df['is_extreme_temp'] & df['is_extreme_precip']

extreme_freq = (
    df.groupby("block")[["is_extreme_temp",
                         "is_extreme_precip",
                         "is_extreme_both"]]
    .sum()
    .div(15)
    .reset_index()
)

# %%
# Original approach
extreme_freq["block_label"] = extreme_freq["block"].map(label_map)
extreme_freq = extreme_freq.sort_values("block")

x_order = [label_map[b] for b in block_ranges.index]

n = len(x_order)

pal = sns.color_palette("viridis", n_colors=n)[::-1]
palette = dict(zip(x_order, pal))

fig, axes = plt.subplots(1, 3, figsize=(16, 5))

vars_to_plot = [
    "is_extreme_temp",
    "is_extreme_precip",
    "is_extreme_both"
]

titles = [
    "Extreme temperature frequency (90th percentile)",
    "Extreme precipitation frequency (95th percentile)",
    "Compound extremes frequency"
]

for ax, var, title in zip(axes, vars_to_plot, titles):

    sns.barplot(
        data=extreme_freq,
        x="block_label",
        y=var,
        order=x_order,
        palette=palette,
        ax=ax,
        hue="block_label",
        legend=False
    )

    ax.set_title(title, pad=12, fontweight='bold')
    ax.set_xlabel("")
    ax.tick_params(axis="x", rotation=45)
    ax.grid(axis="y", alpha=0.3)

    baseline_val = df[baseline_mask][var].sum()/30
    ax.axhline(
        y=baseline_val,
        color='k',
        linestyle='--',
        linewidth=2.5,
        label=f'Baseline ({baseline_val:.1f} days/yr)'
    )

    ax.legend(
        loc="best",
        frameon=True,
        facecolor="lightgrey",
        framealpha=0.6,
        fontsize=8
    )

    for spine in ax.spines.values():
        spine.set_color("black")

axes[0].set_ylabel("Mean annual frequency / days per year", labelpad=10)

for ax in axes[1:]:
    ax.set_ylabel("")

fig.suptitle("Long-term trend in annual frequency of extreme weather events (2006-2080, by period)",
             fontsize=16,
             y=1.05,
             fontweight='bold'
            )

plt.tight_layout(rect=[0, 0, 1, 1.05])
plt.subplots_adjust(wspace=0.2)
plt.savefig('extreme_bars.png', dpi=300, bbox_inches='tight')
plt.draw()
plt.show()

# %% [markdown]
# Explore a more robust approach

# %%
# TREFMXAV_U distribution
percentiles = [85, 90, 95, 99]

percentile_vals = np.percentile(baseline_data['TREFMXAV_U'].dropna(), percentiles)

plt.figure(figsize=(12, 12))

g = sns.displot(baseline_data['TREFMXAV_U'], kde=True)

ax = g.ax

for p, v in zip(percentiles, percentile_vals):
    ax.axvline(v, linestyle='--', linewidth=1.5, label=f'{p}th', color='red')
    ax.text(v, ax.get_ylim()[1]*0.9, f'{p}%', rotation=90,
            va='top', ha='right', fontsize=9)

ax.legend(loc='upper left')
plt.title('TREFMXAV_U distribution and position of extreme percentiles', fontweight='bold')
plt.tight_layout()
plt.savefig('TREFMXAV_U_dist.png', dpi=300, bbox_inches='tight')
plt.draw()
plt.show()

# %%
# PRECT distribution
percentiles = [85, 90, 95, 99]

percentile_vals = np.percentile(baseline_data['PRECT'].dropna(), percentiles)

plt.figure(figsize=(12, 12))

g = sns.displot(baseline_data['PRECT'], kde=True)

ax = g.ax

for p, v in zip(percentiles, percentile_vals):
    ax.axvline(v, linestyle='--', linewidth=1.5, label=f'{p}th', color='red')
    ax.text(v, ax.get_ylim()[1]*0.9, f'{p}%', rotation=90,
            va='top', ha='right', fontsize=9)

ax.legend(loc='upper right')
plt.title('PRECT distribution and position of extreme percentiles', fontweight='bold')
ax.set_xlim(None,4e-7)
plt.tight_layout()
plt.savefig('PRECT_dist.png', dpi=300, bbox_inches='tight')
plt.draw()
plt.show()

# %% [markdown]
# Right skewed distribution, with many days with little/no precipitation is good motivation for specifically conditioning on 'wet days'

# %%
# More rigorous approach to defining extreme thresholds

df2 = df.copy()
baseline2 = baseline_data.copy()

# Convert precipitation into mm/day
for d in (df2, baseline2):
    d['PRECT_mm_day'] = d['PRECT'] * 86400 * 1000

precip_var = 'PRECT_mm_day'

temp_q = 0.90 # extreme heat threshold
precip_q = 0.95 # extreme precip threshold (wet-day percentile)
wet_day_cutoff = 1.0 # min precipitation for wet day

baseline_wet = baseline2[baseline2[precip_var] >= wet_day_cutoff].copy()

# Define temperature threshold by month to make it more seasonally aware
temp_thresh_by_month = (
    baseline2.groupby('month')['TREFMXAV_U']
    .quantile(temp_q)
    .rename('temp_thresh')
    .reset_index()
)

# Precip threshold by month and only using wet days
precip_thresh_by_month = (
    baseline_wet.groupby('month')[precip_var]
    .quantile(precip_q)
    .rename('precip_thresh')
    .reset_index()
)

# Fallbacks in case any month has no wet days in baseline
global_temp_thresh = baseline_data['TREFMXAV_U'].quantile(temp_q)
global_precip_thresh = baseline_wet[precip_var].quantile(precip_q) if len(baseline_wet) > 0 else np.nan

# Merge thresholds into full dataset
df2 = df2.merge(temp_thresh_by_month, on='month', how='left')
df2 = df2.merge(precip_thresh_by_month, on='month', how='left')

# Fill missing thresholds (if any)
df2['temp_thresh'] = df2['temp_thresh'].fillna(global_temp_thresh)
df2['precip_thresh'] = df2['precip_thresh'].fillna(global_precip_thresh)

df2['is_wet_day'] = df2[precip_var] >= wet_day_cutoff
df2['is_extreme_temp'] = df2['TREFMXAV_U'] > df2['temp_thresh']
df2['is_extreme_precip'] = df2['is_wet_day'] & (df2[precip_var] > df2['precip_thresh'])
df2['is_extreme_both'] = df2['is_extreme_temp'] & df2['is_extreme_precip']

# Annual counts (days/year) for each variable within each block
annual_extreme_counts = (
    df2.groupby(['block', 'year'])[['is_extreme_temp', 'is_extreme_precip', 'is_extreme_both']]
    .sum()
    .reset_index()
)

# Then average within each block for mean block annual frequency (days per year)
extreme_freq = (
    annual_extreme_counts.groupby('block')[['is_extreme_temp', 'is_extreme_precip', 'is_extreme_both']]
    .mean()
    .reset_index()
)

# Add display labels
extreme_freq["block_label"] = extreme_freq["block"].map(label_map)
extreme_freq = extreme_freq.sort_values("block")

# X-axis order
x_order = [label_map[b] for b in block_ranges.index]

# Baseline reference values (mean annual frequency in baseline years)
baseline_annual = (
    df2[baseline_mask]
    .groupby('year')[['is_extreme_temp', 'is_extreme_precip', 'is_extreme_both']]
    .sum()
    .reset_index()
)

n = len(x_order)
pal = sns.color_palette("viridis", n_colors=n)[::-1]
palette = dict(zip(x_order, pal))

fig, axes = plt.subplots(1, 3, figsize=(16, 5))

vars_to_plot = [
    "is_extreme_temp",
    "is_extreme_precip",
    "is_extreme_both"
]

titles = [
    f"Extreme temperature frequency\n(>{int(temp_q*100)}th percentile, baseline month-specific)",
    f"Extreme precipitation frequency\n(wet-day >{int(precip_q*100)}th percentile, baseline month-specific)",
    "Compound extremes frequency\n(hot + extreme precipitation)"
]

for ax, var, title in zip(axes, vars_to_plot, titles):

    sns.barplot(
        data=extreme_freq,
        x="block_label",
        y=var,
        order=x_order,
        palette=palette,
        ax=ax,
        hue="block_label",
        legend=False
    )

    ax.set_title(title, pad=12, fontweight='bold')
    ax.set_xlabel("")
    ax.tick_params(axis="x", rotation=45)
    ax.grid(axis="y", alpha=0.3)

    # Baseline mean annual frequency line (computed robustly from annual counts)
    baseline_val = baseline_annual[var].mean()
    ax.axhline(
        y=baseline_val,
        color='k',
        linestyle='--',
        linewidth=2.5,
        label=f'Baseline ({baseline_val:.1f} days/yr)'
    )

    ax.legend(
        loc="best",
        frameon=True,
        facecolor="lightgrey",
        framealpha=0.6,
        fontsize=8
    )

    for spine in ax.spines.values():
        spine.set_color("black")

axes[0].set_ylabel("Mean annual frequency / days per year", labelpad=10)
for ax in axes[1:]:
    ax.set_ylabel("")

fig.suptitle(
    "Long-term trend in annual frequency of extreme weather events (2006–2080, by period)\n"
    f"Thresholds defined from baseline (2006–2035): Temperature={int(temp_q*100)}th percentile by month; "
    f"Precipitation={int(precip_q*100)}th wet-day percentile by month",
    fontsize=14,
    y=1.08,
    fontweight='bold'
)

plt.tight_layout(rect=[0, 0, 1, 1.02])
plt.subplots_adjust(wspace=0.2)
plt.savefig('extreme_bars_improved_thresholds.png', dpi=300, bbox_inches='tight')
plt.show()
